# %%
#!rm -rf

# %%
#!rm -rf

# %%
# Wandb login:
from kaggle_secrets import UserSecretsClient
import wandb
user_secrets = UserSecretsClient()
secret_value = user_secrets.get_secret("wandb_api_key")
wandb.login(key=secret_value)

# %%
import os
import cv2
import random
import numpy as np
import pandas as pd
from tqdm import tqdm
import shutil
from shutil import copyfile
import matplotlib.pyplot as plt
from matplotlib import animation, rc
rc('animation', html='jshtml')
from PIL import Image
import ultralytics
from ultralytics import YOLO
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.45  Python-3.11.8 torch-2.2.2+cpu CPU (11th Gen Intel Core(TM) i5-11400H 2.70GHz)
# Setup complete  (12 CPUs, 15.8 GB RAM, 365.7/464.5 GB disk)

# %%
train_path='C:/Users/FurkanBulut/PycharmProjects/SolarVizyon/datasets/YoloPanel/train_test_poznan_2018_2020_second_model/train'
valid_path='datasets/valid/'
test_path='C:/Users/FurkanBulut/PycharmProjects/SolarVizyon/datasets/YoloPanel/train_test_poznan_2018_2020_second_model/train'

# %%
ano_paths=[]
for dirname, _, filenames in os.walk('C:/Users/FurkanBulut/PycharmProjects/SolarVizyon/datasets/YoloPanel/train_test_poznan_2018_2020_second_model/train'
                                     ''):
    for filename in filenames:
        if filename[-4:]=='.txt':
            ano_paths+=[(os.path.join(dirname, filename))]       
#print(ano_paths)

# %%
n=len(ano_paths) 
print(n)
N=list(range(n))
random.shuffle(N)

train_ratio = 0.8
valid_ratio = 0.2

train_size = int(train_ratio*n)
valid_size = int(valid_ratio*n)

train_i = N[:train_size]
valid_i = N[train_size:]
# Out:
# 652

# %%
tano_paths=[]
for dirname, _, filenames in os.walk('C:/Users/FurkanBulut/PycharmProjects/SolarVizyon/datasets/YoloPanel/train_test_poznan_2018_2020_second_model/test'):
    for filename in filenames:
        if filename[-4:]=='.txt' and filename!='classes.txt':
            tano_paths+=[(os.path.join(dirname, filename))]

# %%
for i in train_i:
    ano_path=ano_paths[i]
    img_path=os.path.join('C:/Users/FurkanBulut/PycharmProjects/SolarVizyon/datasets/YoloPanel/train_test_poznan_2018_2020_second_model/train',
                    ano_path.split('/')[-1][0:-4]+'.jpg')
    try:
        # !cp {ano_path} {train_path}
        # !cp {img_path} {train_path}
    except:
        continue
print(len(os.listdir(train_path)))
# Out:
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# ...

# %%
for i in valid_i:
    ano_path=ano_paths[i]
    img_path=os.path.join('C:/Users/FurkanBulut/PycharmProjects/SolarVizyon/datasets/YoloPanel/train_test_poznan_2018_2020_second_model/train',
                    ano_path.split('/')[-1][0:-4]+'.jpg')
    try:
        # !cp {ano_path} {valid_path}
        # !cp {img_path} {valid_path}
    except:
        continue
print(len(os.listdir(valid_path)))
# Out:
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# ...

# %%
for i in range(len(tano_paths)):
    ano_path=tano_paths[i]
    img_path=os.path.join('C:/Users/FurkanBulut/PycharmProjects/SolarVizyon/datasets/YoloPanel/train_test_poznan_2018_2020_second_model/test',
                    ano_path.split('/')[-1][0:-4]+'.jpg')
    try:
        # !cp {ano_path} {test_path}
        # !cp {img_path} {test_path}
    except:
        continue
print(len(os.listdir(test_path)))
# Out:
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# ...

# %%
import yaml

data_yaml = dict(
    train ='train',
    val ='valid',
    test='test',
    nc =1,
    names =['Solar Panel']
)

with open('data.yaml', 'w') as outfile:
    yaml.dump(data_yaml, outfile, default_flow_style=True)

# %%
names =['Solar Panel']
M=list(range(len(names)))
class_map=dict(zip(M,names))

# %%
model = YOLO("yolov8x.pt")
# Out:
# ...
# 100%|██████████| 131M/131M [02:33<00:00, 891kB/s]

# %%
# !yolo task=detect mode=train model=yolov8x.pt data=data.yaml epochs=30 imgsz=480
# Out:
# Ultralytics YOLOv8.1.45 ðŸš€ Python-3.11.8 torch-2.2.2+cpu CPU (11th Gen Intel Core(TM) i5-11400H 2.70GHz)
# ...

# %%
paths2=[]
for dirname, _, filenames in os.walk('runs/detect/train'):
    for filename in filenames:
        if filename[-4:]=='.jpg':
            paths2+=[(os.path.join(dirname, filename))]
paths2=sorted(paths2)
print(len(paths2))
print(paths2[0:3])
# Out:
# 0
# []

# %%
for path in paths2:
    image = Image.open(path)
    image=np.array(image)
    plt.figure(figsize=(20,10))
    plt.imshow(image)
    plt.show()

# %%
best_path0='runs/detect/train/weights/best.pt'
source0='datasets/test'

# %%
ppaths=[]
for dirname, _, filenames in os.walk(source0):
    for filename in filenames:
        if filename[-4:]=='.jpg':
            ppaths+=[(os.path.join(dirname, filename))]
ppaths=sorted(ppaths)
print(len(ppaths))
# Out:
# 0

# %%
model2 = YOLO(best_path0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 model2 = YOLO(best_path0)
#
# File ~\anaconda3\envs\SolarVizyon\Lib\site-packages\ultralytics\models\yolo\model.py:23, in YOLO.__init__(self, model, task, verbose)
#      20     self.__dict__ = new_instance.__dict__
#      21 else:
#      22     # Continue with default YOLO initialization
# ---> 23     super().__init__(model=model, task=task, verbose=verbose)
#
# File ~\anaconda3\envs\SolarVizyon\Lib\site-packages\ultralytics\engine\model.py:151, in Model.__init__(self, model, task, verbose)
#     149     self._new(model, task=task, verbose=verbose)
#     150 else:
# --> 151     self._load(model, task=task)
#
# File ~\anaconda3\envs\SolarVizyon\Lib\site-packages\ultralytics\engine\model.py:240, in Model._load(self, weights, task)
# ...

# %%
# !yolo task=detect mode=predict model={best_path0} conf=0.3 source={source0}
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\FurkanBulut\anaconda3\envs\SolarVizyon\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\FurkanBulut\anaconda3\envs\SolarVizyon\Lib\site-packages\ultralytics\cfg\__init__.py", line 555, in entrypoint
#     model = YOLO(model, task=task)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\FurkanBulut\anaconda3\envs\SolarVizyon\Lib\site-packages\ultralytics\models\yolo\model.py", line 23, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "C:\Users\FurkanBulut\anaconda3\envs\SolarVizyon\Lib\site-packages\ultralytics\engine\model.py", line 151, in __init__
#     self._load(model, task=task)
#   File "C:\Users\FurkanBulut\anaconda3\envs\SolarVizyon\Lib\site-packages\ultralytics\engine\model.py", line 240, in _load
# ...

# %%
results = model2.predict(source0,conf=0.3)
print(len(results))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 results = model2.predict(source0,conf=0.3)
#       2 print(len(results))
#
# NameError: name 'model2' is not defined

# %%
print((results[0].boxes.data))

# %%
PBOX=pd.DataFrame(columns=range(6))
for i in range(len(results)):
    arri=pd.DataFrame(results[i].boxes.data.cpu().numpy()).astype(float)
    path=ppaths[i]
    file=path.split('/')[-1]
    arri=arri.assign(file=file)
    arri=arri.assign(i=i)
    PBOX=pd.concat([PBOX,arri],axis=0)
PBOX.columns=['x','y','x2','y2','confidence','class','file','i']
display(PBOX)

# %%
PBOX['class']=PBOX['class'].apply(lambda x: class_map[int(x)])
PBOX=PBOX.reset_index(drop=True)
display(PBOX)
display(PBOX['class'].value_counts())

# %%
def draw_box2(n0):
    
    ipath=ppaths[n0]
    image=cv2.imread(ipath)
    H,W=image.shape[0],image.shape[1]
    file=ipath.split('/')[-1]
    
    if PBOX[PBOX['file']==file] is not None:
        box=PBOX[PBOX['file']==file]
        box=box.reset_index(drop=True)
        #display(box)

        for i in range(len(box)):
            label=box.loc[i,'class']
            x=int(box.loc[i,'x'])
            y=int(box.loc[i,'y'])
            x2=int(box.loc[i,'x2']) 
            y2=int(box.loc[i,'y2'])
            #print(label,x,y,x2,y2)
            #cv2.putText(image, f'{label}', (x, int(y-4)), 
            #            cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0,255,0),2)
            cv2.rectangle(image,(x,y),(x2,y2),(0,0,255),2)
    
    #plt.imshow(image)
    #plt.show()   
    
    return image

# %%
def create_animation(ims):
    fig=plt.figure(figsize=(12,8))
    im=plt.imshow(cv2.cvtColor(ims[0],cv2.COLOR_BGR2RGB))
    text = plt.text(0.05, 0.05, f'Slide {0}', transform=fig.transFigure, fontsize=14, color='blue')
    plt.axis('off')
    plt.close()

    def animate_func(i):
        im.set_array(cv2.cvtColor(ims[i],cv2.COLOR_BGR2RGB))
        text.set_text(f'Slide {i}')        
        return [im]    
    
    return animation.FuncAnimation(fig, animate_func, frames=len(ims), interval=1000)

# %%
images2=[]
for i in tqdm(range(len(ppaths))):
    images2+=[draw_box2(i)]
# Out:
# 0it [00:00, ?it/s]

# %%
create_animation(images2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 create_animation(images2)
#
# Cell In[56], line 3, in create_animation(ims)
#       1 def create_animation(ims):
#       2     fig=plt.figure(figsize=(12,8))
# ----> 3     im=plt.imshow(cv2.cvtColor(ims[0],cv2.COLOR_BGR2RGB))
#       4     text = plt.text(0.05, 0.05, f'Slide {0}', transform=fig.transFigure, fontsize=14, color='blue')
#       5     plt.axis('off')
#
# IndexError: list index out of range
